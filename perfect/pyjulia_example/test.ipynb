# %%
import json

from julia.api import Julia
jl = Julia(compiled_modules=False)

from julia import Main


Main.include("fake_mbo.jl")

indexed_designs = json.load(open("designs.json", "r"))

n_designs = Main.fake_mbo(indexed_designs)
assert n_designs == len(indexed_designs)
print("Python calls this a success!")
# Out:
# ---------------------------------------------------------------------------
# JuliaError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import json
#       3 from julia.api import Julia
# ----> 4 jl = Julia(compiled_modules=False)
#       6 from julia import Main
#       9 Main.include("fake_mbo.jl")
#
# File ~/.local/lib/python3.10/site-packages/julia/core.py:525, in Julia.__init__(self, init_julia, jl_init_path, runtime, jl_runtime_path, debug, **julia_options)
#     516     self._call("""
#     517     const PyCall = try
#     518         Base.require({0})
#    (...)
#     522     end
#     523     """.format(PYCALL_PKGID))
#     524 else:
# --> 525     self._call("const PyCall = Base.require({0})".format(PYCALL_PKGID))
#     527 self._call(u"using .PyCall")
#     529 # Whether we initialized Julia or not, we MUST create at least one
#     530 # instance of PyObject and the convert function. Since these will be
#     531 # needed on every call, we hold them in the Julia object itself so
#     532 # they can survive across reinitializations.
#
# File ~/.local/lib/python3.10/site-packages/julia/core.py:561, in Julia._call(self, src)
#     559 # logger.debug("_call(%s)", src)
#     560 ans = self.api.jl_eval_string(src.encode('utf-8'))
# --> 561 self.check_exception(src)
#     563 return ans
#
# File ~/.local/lib/python3.10/site-packages/julia/core.py:615, in Julia.check_exception(self, src)
#     613 else:
#     614     exception = sprint(showerror, self._as_pyobj(res))
# --> 615 raise JuliaError(u'Exception \'{}\' occurred while calling julia code:\n{}'
#     616                  .format(exception, src))
#
# JuliaError: Exception 'ArgumentError' occurred while calling julia code:
# const PyCall = Base.require(Base.PkgId(Base.UUID("438e738f-606a-5dbb-bf0a-cddfbfd45ab0"), "PyCall"))
